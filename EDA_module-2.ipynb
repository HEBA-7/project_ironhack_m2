# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %%
data = pd.read_csv("unicorns till sep 2022.csv")
data
# Out:
#                   Company Valuation ($B) Date Joined        Country  \
# 0               ByteDance           $140    4/7/2017          China
# 1                  SpaceX           $127   12/1/2012  United States
# 2                   SHEIN           $100    7/3/2018          China
# 3                  Stripe            $95   1/23/2014  United States
# 4                   Canva            $40    1/8/2018      Australia
# ...                   ...            ...         ...            ...
# 1181          LeadSquared             $1   6/21/2022          India
# 1182            FourKites             $1   6/21/2022  United States
# 1183          VulcanForms             $1    7/5/2022  United States
# 1184          SingleStore             $1   7/12/2022  United States
# 1185  Unstoppable Domains             $1   7/27/2022  United States
#
#               City                              Industry  \
# 0           Beijing              Artificial intelligence
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         1186 non-null   object
#  1   Valuation ($B)  1186 non-null   object
#  2   Date Joined     1186 non-null   object
#  3   Country         1186 non-null   object
#  4   City            1186 non-null   object
#  5   Industry        1186 non-null   object
#  6   Investors       1168 non-null   object
# dtypes: object(7)
# memory usage: 65.0+ KB

# %%
data["Company"].unique()
# Out:
# array(['ByteDance', 'SpaceX', 'SHEIN', ..., 'VulcanForms', 'SingleStore',
#        'Unstoppable Domains'], dtype=object)

# %%
data["Company"].count()
# Out:
# 1186

# %%
data["Country"].unique()
data["Country"].unique()
# Out:
# array(['China', 'United States', 'Australia', 'United Kingdom', 'Bahamas',
#        'India', 'Indonesia', 'Germany', 'Turkey', 'Hong Kong',
#        'Seychelles', 'Sweden', 'Mexico', 'Estonia', 'Canada',
#        'Netherlands', 'France', 'Israel', 'Finland', 'Colombia',
#        'Belgium', 'Brazil', 'South Korea', 'Denmark', 'Switzerland',
#        'Lithuania', 'Austria', 'Ireland', 'Singapore', 'Vietnam',
#        'United Arab Emirates', 'Argentina', 'Spain', 'Japan',
#        'Luxembourg', 'Nigeria', 'Philippines', 'Croatia', 'Senegal',
#        'Malaysia', 'Bermuda', 'Norway', 'South Africa', 'Ecuador',
#        'Chile', 'Thailand', 'Czech Republic', 'Italy'], dtype=object)

# %%
#sum_comp = data.loc[data["Country"]== "Israel"]
data["Valuation BI"]= data["Valuation ($B)"].str.replace("$", "")
type(data["Valuation BI"])
data["Valuation BI"].unique()
# Out:
# /var/folders/hw/hn42sv9d3y3g8s91ckv76flh0000gn/T/ipykernel_13334/1993962529.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["Valuation BI"]= data["Valuation ($B)"].str.replace("$", "")
# array(['140', '127', '100', '95', '40', '39', '38', '33', '31.50', '32',
#        '27', '25', '22', '20', '17.50', '15.50', '15', '14', '13.50',
#        '13.30', '13', '12.60', '12.59', '12.30', '12', '11.80', '11.70',
#        '11.40', '11.25', '11.10', '11', '10.20', '10.88', '10.70', '10',
#        '9.50', '9.28', '9.23', '9.20', '9.08', '9', '8.75', '8.70',
#        '8.60', '8.50', '8.40', '8.30', '8.10', '8', '7.83', '7.60',
#        '7.75', '7.50', '7.40', '7.30', '7.25', '7.10', '7', '6.80',
#        '6.70', '6.60', '6.51', '6.50', '6.40', '6.30', '6.28', '6.20',
# ...

# %%
#convertimos los strings de la array en floats para que podamos sumarlas
data["Valuation BI"] = data["Valuation BI"].astype(float)
data
# Out:
#                   Company Valuation ($B) Date Joined        Country  \
# 0               ByteDance           $140    4/7/2017          China
# 1                  SpaceX           $127   12/1/2012  United States
# 2                   SHEIN           $100    7/3/2018          China
# 3                  Stripe            $95   1/23/2014  United States
# 4                   Canva            $40    1/8/2018      Australia
# ...                   ...            ...         ...            ...
# 1181          LeadSquared             $1   6/21/2022          India
# 1182            FourKites             $1   6/21/2022  United States
# 1183          VulcanForms             $1    7/5/2022  United States
# 1184          SingleStore             $1   7/12/2022  United States
# 1185  Unstoppable Domains             $1   7/27/2022  United States
#
#               City                              Industry  \
# 0           Beijing              Artificial intelligence
# ...

# %%
print("total:", data["Valuation BI"].sum())
print("max:", data["Valuation BI"].max())
print("min:", data["Valuation BI"].min())
# Out:
# total: 3856.0199999999995
# max: 140.0
# min: 1.0

# %%
#ahora toca separar los investors para ver si se puede jugar con esta variable también
#por ejemplo sacar el dinero que se inverte en cada investor

# %%
#separamos por comas y por columnas los investors
#data[["invest_1", "invest_2", "invest_3", "invest_4"]]= data["Investors"].str.split(pat=",", expand=True)
#data

# %%
#separamos por comas
data[["invest_1", "invest_2", "invest_3", "invest_4"]]= data["Investors"].str.split(pat=",", expand=True)
data.head(10)
# Out:
#         Company Valuation ($B) Date Joined         Country          City   \
# 0     ByteDance           $140    4/7/2017           China        Beijing
# 1        SpaceX           $127   12/1/2012   United States      Hawthorne
# 2         SHEIN           $100    7/3/2018           China       Shenzhen
# 3        Stripe            $95   1/23/2014   United States  San Francisco
# 4         Canva            $40    1/8/2018       Australia    Surry Hills
# 5  Checkout.com            $40    5/2/2019  United Kingdom         London
# 6     Instacart            $39  12/30/2014   United States  San Francisco
# 7    Databricks            $38    2/5/2019   United States  San Francisco
# 8       Revolut            $33   4/26/2018  United Kingdom         London
# 9    Epic Games         $31.50  10/26/2018   United States           Cary
#
#                               Industry  \
# 0              Artificial intelligence
# 1                                Other
# ...

# %%
#Revisamos como están los datos en todos los invest
data["invest_1"].unique()
# Out:
# array(['Sequoia Capital China', 'Founders Fund',
#        'Tiger Global Management', 'Khosla Ventures',
#        'Andreessen Horowitz', 'index Ventures', 'Tencent Holdings', nan,
#        'SoftBank Group', 'Forerunner Ventures', 'GGV Capital',
#        'Hillhouse Capital Management', 'Accel', 'Accel Partners',
#        'Benchmark', 'IDG Capital', 'Lightspeed Venture Partners',
#        'New Enterprise Associates', 'General Catalyst', 'DST Global',
#        'Coatue Management', 'Vickers Venture Partners', 'KKR',
#        'Caffeinated Capital', 'LTW Capital', 'Initialized Capital',
#        'Aviation Industry Corporation of China', 'Activant Capital',
#        'DFJ Growth Fund', 'Accel India', 'MindWorks Ventures',
#        'Index Ventures', 'General Catalyst Partners', 'Y Combinator',
#        'DJF', 'Upper90', 'Ribbit Capital', 'Bessemer Venture Partners',
#        'Redalpine Venture Partners', 'Summit Partners', 'Vattenfall',
# ...

# %%
#Quitamos los espacios de delante y detrás de los strings
data["invest_1"] = data["invest_1"].str.strip(" ")
data["invest_2"] = data["invest_2"].str.strip(" ")
data["invest_3"] = data["invest_3"].str.strip(" ")
data["invest_4"] = data["invest_4"].str.strip(" ")

# %%
#Revisamos que todo bien
data["invest_2"].unique()
# Out:
# array(['SIG Asia Investments', 'Draper Fisher Jurvetson',
#        'Sequoia Capital China', 'LowercaseCapital', 'Blackbird Ventures',
#        'Insight Partners', 'Kleiner Perkins Caufield & Byers',
#        'New Enterprise Associates', 'DST Global', 'KKR', nan,
#        'Andreessen Horowitz', 'Crosslink Capital',
#        'Lightspeed India Partners', 'ZhenFund', 'Boyu Capital',
#        'AltaIR Capital', 'Warbug Pincus', 'Sequoia Capital',
#        'Greylock Partners', 'Softbank Group', 'Longfor Capitalm',
#        'Venture51', 'Google Ventures', 'Spar Capital',
#        'Thirty Five Ventures', '83North',
#        'Institutional Venture Partners', 'F-Prime Capital',
#        'Forerunner Ventures', 'Ribbit Capital', None, 'IKEA GreenTech',
#        'BDT Capital Partners', 'Tencent Holdings', 'Spark Capital', 'CRV',
#        'Legend Capital', 'Y Combinator', 'Essence Financial',
#        'Tribe Capital', 'Coatue Management',
#        'Hillhouse Capital Management', 'SAIF Partners',
# ...

# %%
data.head(5)
# Out:
#      Company Valuation ($B) Date Joined        Country          City   \
# 0  ByteDance           $140    4/7/2017          China        Beijing
# 1     SpaceX           $127   12/1/2012  United States      Hawthorne
# 2      SHEIN           $100    7/3/2018          China       Shenzhen
# 3     Stripe            $95   1/23/2014  United States  San Francisco
# 4      Canva            $40    1/8/2018      Australia    Surry Hills
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                            Investors  Valuation BI  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         140.0
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...         127.0
# 2  Tiger Global Management, Sequoia Capital China...         100.0
# ...

# %%
#Revisamos los nans que hay en las diferentes columnas
print(data["invest_4"].isna().sum())
print(data["invest_3"].isna().sum())
print(data["invest_2"].isna().sum())
print(data["invest_1"].isna().sum())
print(data["Investors"].isna().sum())
# Out:
# 1176
# 159
# 68
# 18
# 18

# %%
#la suma de todos los otros nans, coincide con el cruce de todo el dataset
data.isna().sum().sum()
# Out:
# 1439

# %%
#los None, los convertimos en nans y string
data["invest_1"] = data["invest_1"].fillna("")
data["invest_2"] = data["invest_2"].fillna("")
data["invest_3"] = data["invest_3"].fillna("")
data["invest_4"] = data["invest_4"].fillna("")
data["invest_4"].unique()
# Out:
# array(['Softbank Group', 'nan', 'Spark Capital',
#        'SDIC CMC Investment Management', 'Redpoint e.ventures',
#        'Redpoint Ventures', 'Goldman Sachs', 'Nirvana Venture Advisors',
#        '', 'Accel', 'McKesson Ventures'], dtype=object)

# %%
data["data_1"] = data["invest_1"].str.replace("nan", "")
data["data_2"] = data["invest_2"].str.replace("nan", "")
data["data_3"] = data["invest_3"].str.replace("nan", "")
data["data_4"] = data["invest_4"].str.replace("nan", "")

# %%
#revisamos y confirmamos
data["invest_4"].unique()
# Out:
# array(['Softbank Group', 'nan', 'Spark Capital',
#        'SDIC CMC Investment Management', 'Redpoint e.ventures',
#        'Redpoint Ventures', 'Goldman Sachs', 'Nirvana Venture Advisors',
#        '', 'Accel', 'McKesson Ventures'], dtype=object)

# %%
data
# Out:
#                   Company Valuation ($B) Date Joined        Country  \
# 0               ByteDance           $140  2017-04-07          China
# 1                  SpaceX           $127  2012-12-01  United States
# 2                   SHEIN           $100  2018-07-03          China
# 3                  Stripe            $95  2014-01-23  United States
# 4                   Canva            $40  2018-01-08      Australia
# ...                   ...            ...         ...            ...
# 1181          LeadSquared             $1  2022-06-21          India
# 1182            FourKites             $1  2022-06-21  United States
# 1183          VulcanForms             $1  2022-07-05  United States
# 1184          SingleStore             $1  2022-07-12  United States
# 1185  Unstoppable Domains             $1  2022-07-27  United States
#
#               City                              Industry  \
# 0           Beijing              Artificial intelligence
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         1186 non-null   object
#  1   Valuation ($B)  1186 non-null   object
#  2   Date Joined     1186 non-null   datetime64[ns]
#  3   Country         1186 non-null   object
#  4   City            1186 non-null   object
#  5   Industry        1186 non-null   object
#  6   Investors       1168 non-null   object
#  7   Valuation BI    1186 non-null   float64
#  8   invest_1        1186 non-null   object
#  9   invest_2        1186 non-null   object
#  10  invest_3        1186 non-null   object
#  11  invest_4        1186 non-null   object
#  12  data_1          1186 non-null   object
#  13  data_2          1186 non-null   object
#  14  data_3          1186 non-null   object
#  15  data_4          1186 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(14)
# ...

# %%
data.describe()
# Out:
#        Valuation BI
# count   1186.000000
# mean       3.251282
# std        7.641574
# min        1.000000
# 25%        1.100000
# 50%        1.600000
# 75%        3.000000
# max      140.000000

# %%
#Ahora pasamos a revisar las fechas

# %%
data["Date Joined"] = data["Date Joined"].apply(pd.to_datetime)

# %%
data["Date Joined"].unique()
# Out:
# array(['2017-04-07T00:00:00.000000000', '2012-12-01T00:00:00.000000000',
#        '2018-07-03T00:00:00.000000000', '2014-01-23T00:00:00.000000000',
#        '2018-01-08T00:00:00.000000000', '2019-05-02T00:00:00.000000000',
#        '2014-12-30T00:00:00.000000000', '2019-02-05T00:00:00.000000000',
#        '2018-04-26T00:00:00.000000000', '2018-10-26T00:00:00.000000000',
#        '2021-07-20T00:00:00.000000000', '2012-06-06T00:00:00.000000000',
#        '2019-03-05T00:00:00.000000000', '2017-07-25T00:00:00.000000000',
#        '2016-03-31T00:00:00.000000000', '2021-04-07T00:00:00.000000000',
#        '2022-01-05T00:00:00.000000000', '2017-05-31T00:00:00.000000000',
#        '2015-01-23T00:00:00.000000000', '2018-04-20T00:00:00.000000000',
#        '2020-10-08T00:00:00.000000000', '2020-03-01T00:00:00.000000000',
#        '2019-12-20T00:00:00.000000000', '2021-02-17T00:00:00.000000000',
#        '2018-12-11T00:00:00.000000000', '2018-06-26T00:00:00.000000000',
# ...

# %%
data.head(5)
# Out:
#      Company Valuation ($B) Date Joined        Country          City   \
# 0  ByteDance           $140  2017-04-07          China        Beijing
# 1     SpaceX           $127  2012-12-01  United States      Hawthorne
# 2      SHEIN           $100  2018-07-03          China       Shenzhen
# 3     Stripe            $95  2014-01-23  United States  San Francisco
# 4      Canva            $40  2018-01-08      Australia    Surry Hills
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                            Investors  Valuation BI  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         140.0
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...         127.0
# 2  Tiger Global Management, Sequoia Capital China...         100.0
# ...

# %%
data["Date Joined"].sort_values(ascending=False)
# Out:
# 338   2022-08-24
# 561   2022-08-17
# 729   2022-08-16
# 525   2022-08-16
# 605   2022-08-16
#          ...
# 11    2012-06-06
# 435   2012-02-13
# 99    2011-12-12
# 119   2011-04-02
# 710   2007-07-02
# Name: Date Joined, Length: 1186, dtype: datetime64[ns]

# %%
data
# Out:
#                   Company Valuation ($B) Date Joined        Country  \
# 0               ByteDance           $140  2017-04-07          China
# 1                  SpaceX           $127  2012-12-01  United States
# 2                   SHEIN           $100  2018-07-03          China
# 3                  Stripe            $95  2014-01-23  United States
# 4                   Canva            $40  2018-01-08      Australia
# ...                   ...            ...         ...            ...
# 1181          LeadSquared             $1  2022-06-21          India
# 1182            FourKites             $1  2022-06-21  United States
# 1183          VulcanForms             $1  2022-07-05  United States
# 1184          SingleStore             $1  2022-07-12  United States
# 1185  Unstoppable Domains             $1  2022-07-27  United States
#
#               City                              Industry  \
# 0           Beijing              Artificial intelligence
# ...

# %%
data_1 = data.loc[data.iloc[:,4]== "Artificial intelligence"]
data_1
# Out:
#                         Company Valuation ($B) Date Joined    Country  \
# 482  Advance Intelligence Group             $2  2021-09-23  Singapore
# 495                        Trax             $2  2019-07-22  Singapore
#
#                        City   \
# 482  Artificial intelligence
# 495  Artificial intelligence
#
#                                               Industry Investors  \
# 482        Vision Plus Capital, GSR Ventures, ZhenFund       NaN
# 495  Hopu Investment Management, Boyu Capital, DC T...       NaN
#
#      Valuation BI invest_1 invest_2 invest_3 invest_4 data_1 data_2 data_3  \
# 482           2.0      nan      nan      nan      nan
# 495           2.0      nan      nan      nan      nan
#
#     data_4
# 482
# 495

# %%
data_2 = data.loc[data.iloc[:,4]== "Austin"]
data_2
# Out:
#               Company Valuation ($B) Date Joined        Country   City   \
# 322          Workrise          $2.90  2019-09-30  United States  Austin
# 556       ZenBusiness          $1.70  2021-11-09  United States  Austin
# 594           ICON 3D          $1.57  2022-02-18  United States  Austin
# 680    SparkCognition          $1.40  2022-01-25  United States  Austin
# 732     Everly Health          $1.30  2020-12-03  United States  Austin
# 907             Wheel          $1.01  2022-01-19  United States  Austin
# 932      Kendra Scott             $1  2016-12-21  United States  Austin
# 1007        The Zebra             $1  2021-04-12  United States  Austin
# 1115  Iodine Software             $1  2021-12-01  United States  Austin
# 1159            FLASH             $1  2022-03-16  United States  Austin
#
#                              Industry  \
# 322      Internet software & services
# 556                           Fintech
# 594                          Hardware
# ...

# %%
""" revisar porque no me cuadra el sector... parece que hay Investors también"""
data['Industry'].unique()
# Out:
# array(['Artificial intelligence', 'Other',
#        'E-commerce & direct-to-consumer', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics',
#        'Sequoia Capital, Thoma Bravo, Softbank', 'Edtech', 'Hardware',
#        'Consumer & retail', 'Health', 'Auto & transportation',
#        'Cybersecurity', 'Mobile & telecommunications', 'Travel',
#        'Kuang-Chi',
#        'Tiger Global Management, Tiger Brokers, DCM Ventures',
#        'Jungle Ventures, Accel, Venture Highway',
#        'Artificial Intelligence', 'GIC. Apis Partners, Insight Partners',
#        'Vision Plus Capital, GSR Ventures, ZhenFund',
#        'Hopu Investment Management, Boyu Capital, DC Thomson Ventures',
#        'Internet', '500 Global, Rakuten Ventures, Golden Gate Ventures',
#        'Sequoia Capital China, ING, Alibaba Entrepreneurs Fund',
#        'Sequoia Capital China, Shunwei Capital Partners, Qualgro',
# ...

# %%
#data.iloc[:,4]

# %%
#guardamos el csv

# %%
data_unicorns = data.to_csv('unicorns_startups.csv', index=False)
